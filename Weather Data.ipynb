# %%
# Python code to display schematic weather details
import requests
#Sending requests to get the IP Location Information
res = requests.get('https://ipinfo.io/')
# Receiving the response in JSON format
data = res.json()
# Extracting the Location of the City from the response
citydata = data['city']
# Prints the Current Location
print(citydata)
# Passing the City name to the url
url = 'https://wttr.in/{}'.format(citydata)
# Getting the Weather Data of the City
res = requests.get(url)
# Printing the results!
print(res.text)
# This code is contributed by PL VISHNUPPRIYAN
# Out:
# Mumbai
# Weather report: Mumbai
#
#    _`/"".-.     Light rain shower
#     ,\_(   ).   +28(32) °C
#      /(___(__)  ↗ 31 km/h
#        ‘ ‘ ‘ ‘  10 km
#       ‘ ‘ ‘ ‘   0.7 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 29 Jul ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│
# │   ,\_(   ).   +27(32) °C     │   ,\_(   ).   +27(32) °C     │   ,\_(   ).   +27(32) °C     │   ,\_(   ).   +27(32) °C     │
# │    /(___(__)  → 23-46 km/h   │    /(___(__)  ↗ 31-46 km/h   │    /(___(__)  → 28-40 km/h   │    /(___(__)  ↗ 27-46 km/h   │
# │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │
# │     ‘ ‘ ‘ ‘   1.4 mm | 100%  │     ‘ ‘ ‘ ‘   2.1 mm | 100%  │     ‘ ‘ ‘ ‘   1.5 mm | 100%  │     ‘ ‘ ‘ ‘   1.0 mm | 100%  │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 30 Jul ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Patchy light d…│
# │   ,\_(   ).   +27(32) °C     │   ,\_(   ).   +28(33) °C     │   ,\_(   ).   +28(33) °C     │   ,\_(   ).   +28(33) °C     │
# │    /(___(__)  ↗ 32-54 km/h   │    /(___(__)  ↗ 32-43 km/h   │    /(___(__)  ↗ 34-48 km/h   │    /(___(__)  ↗ 32-45 km/h   │
# │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  5 km           │
# │     ‘ ‘ ‘ ‘   0.5 mm | 100%  │     ‘ ‘ ‘ ‘   0.6 mm | 100%  │     ‘ ‘ ‘ ‘   1.2 mm | 100%  │     ‘ ‘ ‘ ‘   0.4 mm | 100%  │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Wed 31 Jul ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│  _`/"".-.     Light rain sho…│
# │   ,\_(   ).   +27(32) °C     │   ,\_(   ).   +27(32) °C     │   ,\_(   ).   +28(32) °C     │   ,\_(   ).   +27(32) °C     │
# │    /(___(__)  ↗ 31-47 km/h   │    /(___(__)  ↗ 28-39 km/h   │    /(___(__)  ↗ 29-41 km/h   │    /(___(__)  ↗ 28-48 km/h   │
# │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │      ‘ ‘ ‘ ‘  10 km          │
# │     ‘ ‘ ‘ ‘   0.7 mm | 100%  │     ‘ ‘ ‘ ‘   1.3 mm | 100%  │     ‘ ‘ ‘ ‘   1.1 mm | 100%  │     ‘ ‘ ‘ ‘   1.2 mm | 100%  │
# └──────────────────────────────┴──────────────────────────────┴──────────────────────────────┴──────────────────────────────┘
# Location: Mumbai, Greater Bombay, Maharashtra, India [18.9321862,72.8308337]
#
# Follow @igor_chubin for wttr.in updates
